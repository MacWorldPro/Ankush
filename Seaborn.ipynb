# %% [markdown]
# <a href="https://colab.research.google.com/github/MacWorldPro/Ankush/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1:
#
# PairPlot:  It shows joint and marginal distributions for all pairwise relationships and for each variable.
#
# JointPlot: It plots the joint distribution between two variables along with each variable’s marginal distribution.
#
# catplot: It is used for visualising categorical data.
#
# distplot:  The seaborn function displot() supports several approaches to visualizing distributions.These include classic techniques like histograms and computationally-intensive approaches like kernel density estimation
#
# relplot: The function relplot() is named that way because it is designed to visualize many different statistical relationships.

# %%
import seaborn as sns
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# Q2:

# %%
sns.lineplot(x="timepoint", y="signal",data=fmri,hue="event",style="region")

# %% [markdown]
# Q3:

# %%
titanic=sns.load_dataset("titanic")
titanic.head()

# %%
sns.boxplot(x="pclass",y="age",data=titanic)

# %%
sns.boxplot(x="pclass",y="fare",data=titanic)

# %%
diamonds=sns.load_dataset("diamonds")
diamonds.head()

# %%
sns.histplot(data=diamonds,y="price",hue="cut")

# %% [markdown]
# Q4:

# %%
iris=sns.load_dataset("iris")
iris.head()

# %%
sns.pairplot(data=iris,hue="species")

# %% [markdown]
# Q5:

# %%
flights=sns.load_dataset("flights")

flights.head()

# %%
flights_pivot = flights.pivot_table(index='month', columns='year', values='passengers')

# %%
sns.heatmap(flights_pivot, annot=True, fmt="d", cmap="YlGnBu")
# Out:
# <Axes: xlabel='year', ylabel='month'>
